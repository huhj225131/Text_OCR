# %%
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import io

# %%
train_df = pd.read_parquet(r"D:\AI_eng\Text_OCR\data\IAM-line\data\train.parquet")

# %%
train_df.describe()
# Out:
#                                                      text  \
# count                                                6482
# unique                                               6046
# top     ' What a frightful event ! ' he wrote . ' I tr...
# freq                                                    8
#
#                                                     image
# count                                                6482
# unique                                               6482
# top     {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# freq                                                    1

# %%
img_bytes= train_df.iloc[0]["image"]["bytes"]
img = Image.open(io.BytesIO(img_bytes))
plt.imshow(img)

# %%
train_df.iloc[0]["text"]
# Out:
# 'put down a resolution on the subject'
