# %%
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image,ImageOps
import io

# %%
train_df = pd.read_parquet(r"D:\AI_eng\Text_OCR\data\IAM-line\data\test.parquet")

# %%
train_df.describe()
# Out:
#                                              text  \
# count                                        2915
# unique                                       2913
# top     SOME years ago a contemporary philosopher
# freq                                            2
#
#                                                     image
# count                                                2915
# unique                                               2915
# top     {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# freq                                                    1

# %%
index = 1000

# %%
img_bytes= train_df.iloc[index]["image"]["bytes"]
img = Image.open(io.BytesIO(img_bytes))
img = ImageOps.grayscale(img) 

img = img.resize((960, 480))

# %%
plt.imshow(img, cmap="gray")

# %%
train_df.iloc[index]["text"]
# Out:
# 'fainting appetite and added a more exquisite and'
