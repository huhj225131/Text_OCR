# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

print(PROJECT_ROOT)
from datasets import EMNIST
# Out:
# d:\AI_eng\Text_OCR

# %%
dataset = EMNIST()
# Out:
# 100%|██████████| 562M/562M [00:15<00:00, 37.2MB/s]

# %%
import matplotlib.pyplot as plt

# %%
x, y =dataset.trainset[100]

# %%
y
# Out:
# 53

# %%
img_np = x[0].squeeze().numpy()
img_fixed = img_np.T
plt.imshow(img_fixed, cmap="gray")
plt.axis("off")
plt.show()
